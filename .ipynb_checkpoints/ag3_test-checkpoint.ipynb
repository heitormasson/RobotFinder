# %%
import numpy as np
import roboticstoolbox as rtb
from roboticstoolbox import *
from spatialmath import *
from math import pi
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import cm
import random
import RobotUtils
import copy
from AGS import *
# %matplotlib notebook

# %%
ag2_o=[[0.59681803, 0.21747243, 0.39117939, 0.49950278, 0.75516074, 0.89504478], #do alg que eu rodei de madrugada
       [0.08075314, 0.70706553, 0.54538945, 0.49932118, 0.83698064, 0.19472351], #do alg que o Heitor rodou de madrugada
       [0.51057169, 0.38442273, 0.51855007, 0.67960464, 0.61136335, 0.68145984], #primeiro que deu 15 ontem
       [0.46290208, 0.51460497, 0.,         0.58852252, 1.,         1.,        ]] #segundo que deu 15 ontem

# %%
cr_rpr=[7.034074269195725,
 3.13570912916843,
 8.147364970176415,
 6.167147649872807,
 3.3419663586252346,
 5.412215412121486,
 4.230202084497921,
 8.370860717843653,
 4.905287837072795]

cr_rrr=[13.717345490539937,
 4.615125654537784,
 7.3181389976828815,
 0.18749410340451755,
 4.545036920092833,
 0.6009376177520614,
 3.7922700329035255,
 13.482309207488072,
 14.647104086037793]

cr_teste=[4.546171274792251,
 5.534515059255084,
 5.583453567840804,
 5.420078611580011,
 4.150265780900641,
 1.6957126443709942,
 8.834547752493544,
 10.398819326299513,
 11.835767072435656]

cr=cr_teste
const_list=cr[0:3]
a_list=cr[3:6]
alpha_list=cr[6:9]
robot = robot_build_funcs['RRR']('', const_list, a_list, alpha_list)
sel_tech='EL' # 'EL' or 'TN' OBS: so acompanha a media de forma rigida se for elitimos (isso ja era esperado)
co_tech='AVG' # 'AVG' or 'BST' or 'RAN'
label_idx=0
cr=ag2_o[1]
juntas=[[1,1,1],
        [2,2,2],
        [3,3,3],
        [4,4,4],
        [5,5,5],
        [6,6,6],
        [7,7,7]]

ag3_list=[]
cr_ag3= [0.5986967 , 0.7565645 , 0.68181428, 0.10630019, 0.84590102, 0.54054651, 0.01740973]
for junta_idx in range(len(juntas)):
    if(junta_idx==0):
        juntas_init=[0,0,0]
    else:
        juntas_init=last_solution
    P0=juntas[junta_idx]
    num_ind = int(cr_ag3[0]*49)+1  # [1,50]
    mut_rate = cr_ag3[1]*0.5 + 0.5  # [0.5, 1]
    to_kill_perc = cr_ag3[2]  # [0,1]
    mut_mag = cr_ag3[3]*2+0.001   # [0.001,2] 
    exp_decay = cr_ag3[4]   #  [0, 1]
    step = int(cr_ag3[5]*99)+1   # [1, 100]
    to_kill_freq = int(cr_ag3[6]*74)+1 #[1,75]
    #print(juntas[junta_idx],juntas_init)
    ag3=AG3Int(num_ind,robot,juntas_init,
               P0,mut_rate,co_tech,sel_tech,to_kill_perc,to_kill_freq,mut_mag,exp_decay,step)
    ag3.run(100)
    last_solution=list(ag3.individuals[ag3.best_idx]['cr'])
    ag3_list.append(ag3)
    #plt.plot(ag3.mean_list,linewidth=2.5,label=label_idx)
    plt.plot(ag3.best_score_list,linewidth=2.5,label=label_idx)
    label_idx+=1
plt.show()
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
ag3_list[0].robot.fkine([-16.00008896, 16.00008896, -12.00006672])

# %%
ag3_list[0].robot

# %%
q_gif=np.array([[-1.00000556, 11.00006116, -5.0000278],
 [-12.00006672, 18.000100079999996, -10.0000556],
 [-16.00008896, 16.00008896, -12.00006672],
 [-10.0000556, 16.00008896, -18.000100079999996],
 [-5.0000278, 7.00003892, -21.00011675999999],
 [-5.0000278, 13.00007228, -27.00015011999998],
 [-5.0000278, 13.00007228, -33.00018347999997]])

ag3_list[0].robot.plot(q_gif,dt=1) #roda dnv, pra vc ver o gif

# %%
ag3_list[1].plot_q_gif(cmap='Reds')

# %%
#ag3_list[1].video_q_gif()
